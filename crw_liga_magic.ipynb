# %% [markdown]
# <a href="https://colab.research.google.com/github/hskity/crw-liga-mtg/blob/main/crw_liga_magic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install unidecode bs4
# Out:
# Requirement already satisfied: unidecode in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (0.0.1)
# ERROR: Could not find a version that satisfies the requirement csv (from versions: none)
# ERROR: No matching distribution found for csv

# %%
import csv
import re
import requests
import unidecode
from bs4 import BeautifulSoup
from urllib.error import HTTPError, URLError
import pandas as pd

df_cartas = pd.read_csv('cartas.csv', index_col= None, names = ["cartas"])
cartas = df_cartas["cartas"].tolist()

output = list([["nome", "menorvalor", "maiorvalor"]])

for card in cartas:

  card = card.replace(" ","+")
  card = card.replace(",","%2C")

  website = ("https://www.ligamagic.com.br/?view=cards/card&card="+card)
  headers = {
              'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
  print("Website:", website)
  page = requests.get(website, headers=headers, timeout=20)
  page = page.text
  soup = BeautifulSoup(page, 'lxml')

  nome = soup.find("title").get_text()
  nome = nome.replace(" | Busca de Cards | LigaMagic","")
  print(nome)

  trackpreco = soup.find("div", id="alerta-preco")
  menorpreco = trackpreco.find("div", class_="col-xl-6 col-6 b preco-menor")
  menorvalor = menorpreco.find("font", class_="bigger").get_text()
  print(menorvalor)
  maiorpreco = trackpreco.find("div", class_="col-xl-6 col-6 b preco-maior")
  maiorvalor = maiorpreco.find("font", class_="bigger").get_text()
  print(maiorvalor)

  linha_output =list([nome,menorvalor,maiorvalor])
  output.append(linha_output)
  df_output = pd.DataFrame(output, index=None, columns=None)
  df_output.to_csv('output.csv', index=False, na_rep="Unknown")
# Out:
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Access+Tunnel
# Túnel de Acesso / Access Tunnel
# 0,24
# 6,00
# Website: https://www.ligamagic.com.br/?view=cards/card&card=AEtherize
# Eterificar / Ætherize
# 0,24
# 24,94
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Ambush+Viper
# Víbora de Emboscada / Ambush Viper
# 0,05
# 5,98
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Barkchannel+Pathway
# Senda do Canal da Cortiça / Barkchannel Pathway
# 23,73
# 119,75
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Bident+of+Thassa
# Bidente de Tassa / Bident of Thassa
# 4,75
# 19,99
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Blight+Mamba
# Mamba Assoladora / Blight Mamba
# 2,08
# 12,99
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Borrowing+100%2C000+Arrows
# Borrowing 100,000 Arrows
# 0,07
# 19,90
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Bounty+of+the+Luxa
# Dádiva do Luxa / Bounty of the Luxa
# 0,23
# 6,69
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Broodbirth+Viper
# Broodbirth Viper
# 0,36
# 3,51
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Coat+of+Arms
# Escudo de Armas / Coat of Arms
# 59,90
# 150,00
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Coiling+Oracle
# Oráculo Enroscado / Coiling Oracle
# 0,20
# 25,00
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Command+Tower
# Torre de Comando / Command Tower
# 1,50
# 399,99
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Commander's+Sphere
# Esfera do Comandante / Commander's Sphere
# 0,25
# 95,00
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Cultivate
# Cultivar / Cultivate
# 1,00
# 119,75
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Cyclonic+Rift
# Fenda Ciclônica / Cyclonic Rift
# 67,28
# 299,75
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Desert+of+the+Indomitable
# Deserto do Indômito / Desert of the Indomitable
# 0,06
# 4,90
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Devastation+Tide
# Maré da Devastação / Devastation Tide
# 6,65
# 49,94
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Emergence+Zone
# Zona de Emergência / Emergence Zone
# 0,43
# 91,77
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Fynn%2C+the+Fangbearer
# Fynn, o Portador da Presa / Fynn, the Fangbearer
# 0,34
# 24,75
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Glass+Asp
# Áspide de Vidro / Glass Asp
# 0,08
# 3,90
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Haunted+Cloak
# Manto Assombrado / Haunted Cloak
# 0,12
# 8,99
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Hexdrinker
# Magissorvedora / Hexdrinker
# 132,49
# 449,70
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Honored+Hydra
# Hidra Honrada / Honored Hydra
# 0,23
# 9,90
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Hooded+Hydra
# Hidra Encapuzada / Hooded Hydra
# 2,00
# 22,12
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Ice-Fang+Coatl
# Coatl Presa-de-gelo / Ice-Fang Coatl
# 33,52
# 261,25
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Jewel-Eyed+Cobra
# Naja Olho-de-joia / Jewel-Eyed Cobra
# 0,15
# 2,00
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Kaseto%2C+Orochi+Archmage
# Kaseto, Arquimago Orochi / Kaseto, Orochi Archmage
# 2,49
# 32,49
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Kashi-Tribe+Elite
# Elite da Tribo do Kashi / Kashi-Tribe Elite
# 0,74
# 17,95
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Lonis%2C+Cryptozoologist
# Lonis, Criptozoólogo / Lonis, Cryptozoologist
# 4,40
# 79,95
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Lorescale+Coatl
# Coatl das Escamas Sábias / Lorescale Coatl
# 0,10
# 8,75
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Lotus+Cobra
# Cobra de Lótus / Lotus Cobra
# 14,07
# 350,00
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Marsh+Viper
# Víbora do Brejo / Marsh Viper
# 0,05
# 9,75
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Moss+Viper
# Víbora do Musgo / Moss Viper
# 0,05
# 1,85
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Mystic+Snake
# Serpente Mística / Mystic Snake
# 0,95
# 139,95
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Ohran+Frostfang
# Presa-gélida de Ohran / Ohran Frostfang
# 79,00
# 119,75
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Ohran+Viper
# Víbora de Ohran / Ohran Viper
# 0,45
# 70,00
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Ophidian
# Ofídio / Ophidian
# 0,07
# 1,25
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Orochi+Hatchery
# Incubadora Orochi / Orochi Hatchery
# 0,45
# 25,00
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Orochi+Sustainer
# Provedor Orochi / Orochi Sustainer
# 0,04
# 6,00
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Patagia+Viper
# Víbora com Patágio / Patagia Viper
# 0,15
# 3,00
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Patron+of+the+Orochi
# Patrono dos Orochi / Patron of the Orochi
# 10,41
# 39,90
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Pistus+Strike
# Ataque de Pistus / Pistus Strike
# 0,05
# 1,99
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Plummet
# Tombar / Plummet
# 0,04
# 2,97
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Primal+Empathy
# Empatia Primal / Primal Empathy
# 0,13
# 6,21
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Prowling+Serpopard
# Serpopardo Espreitador / Prowling Serpopard
# 12,98
# 76,50
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Quietus+Spike
# Espículo Quietus / Quietus Spike
# 8,00
# 47,95
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Rampant+Growth
# Crescimento Exuberante / Rampant Growth
# 0,10
# 65,00
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Realmwalker
# Andarilho dos Reinos / Realmwalker
# 19,44
# 99,75
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Reconnaissance+Mission
# Missão de Reconhecimento / Reconnaissance Mission
# 0,25
# 6,90
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Reflections+of+Littjara
# Reflexos de Littjara / Reflections of Littjara
# 5,51
# 79,75
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Reliquary+Tower
# Torre do Relicário / Reliquary Tower
# 6,70
# 79,95
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Rhonas's+Monument
# Monumento de Rhonas / Rhonas's Monument
# 0,62
# 25,16
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Rogue's+Passage
# Passagem do Ladino / Rogue's Passage
# 0,45
# 34,25
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Sabertooth+Cobra
# Naja Dente de Sabre / Sabertooth Cobra
# 0,10
# 1,00
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Sachi%2C+Daughter+of+Seshiro
# Sachi, Filha de Seshiro / Sachi, Daughter of Seshiro
# 0,45
# 29,99
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Sakura-Tribe+Elder
# Ancião da Tribo Sakura / Sakura-Tribe Elder
# 1,99
# 99,00
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Sakura-Tribe+Springcaller
# Convocadora Vernal da Tribo Sakura / Sakura-Tribe Springcaller
# 0,10
# 7,75
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Scavenger+Grounds
# Território dos Necrófagos / Scavenger Grounds
# 5,08
# 40,00
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Seshiro+the+Anointed
# Seshiro, o Ungido / Seshiro the Anointed
# 17,90
# 88,32
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Simic+Charm
# Amuleto Simic / Simic Charm
# 0,29
# 15,65
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Skullclamp
# Pinça Craniana / Skullclamp
# 15,90
# 165,37
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Snake+Basket
# Cesto de Serpentes / Snake Basket
# 2,25
# 20,00
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Sosuke's+Summons
# Invocações de Sosuke / Sosuke's Summons
# 1,25
# 24,75
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Sosuke%2C+Son+of+Seshiro
# Sosuke, Filho de Seshiro / Sosuke, Son of Seshiro
# 0,45
# 12,00
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Stonecoil+Serpent
# Serpente Litoespiral / Stonecoil Serpent
# 9,99
# 149,90
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Temple+of+Mystery
# Templo do Mistério / Temple of Mystery
# 1,90
# 49,75
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Thought+Vessel
# Receptáculo de Pensamentos / Thought Vessel
# 9,33
# 129,99
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Time+of+Need
# Tempo de Necessidade / Time of Need
# 3,00
# 199,75
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Vineglimmer+Snarl
# Liame da Luminovinha / Vineglimmer Snarl
# 8,10
# 100,00
# Website: https://www.ligamagic.com.br/?view=cards/card&card=Winged+Coatl
# Coatl Alado / Winged Coatl
# 0,12
# 7,00
